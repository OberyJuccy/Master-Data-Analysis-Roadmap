# %% [markdown]
# <a href="https://colab.research.google.com/github/OberyJuccy/Master-Data-Analysis-Roadmap/blob/main/SQL/sql-basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * RDBMS is where your SQL code is executed, and then a SQL editor is a user friendly place to write your SQL code.
# * **GROUP BY** allows us to take a look at all the rows in our table, separate them out into different groups and make a calculation for each group.
# * whenever I do a GROUP BY, I have to specify exactly what I want to see within my Select clause as well.
# * **HAVING** clause allows us to do is filter this data right here.
# * **WHERE** clause allowed us to filter on our original table. The **HAVING** clause allows us to filter on our group data.
# * five aggregate functions(pair with GROUP BY) within SQL: COUNT, MIN, MAX, AVG, SUM
# * Percent sign**(%)** in **LIKE** clause is called the wildcard. And that just means that this can be any text. e.g.:SELECT * FROM students WHERE email LIKE '%.edu'
# * **CASE** statements is that we're able to do if else logic within SQL.
# * comment-out a single line from your SQL code: --this is a comment
